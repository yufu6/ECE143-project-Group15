# %%
from chart_studio import plotly as py
import pandas as pd
import plotly.io as pio

# %%
import requests
import json
import csv
import plotly.graph_objs as go
import numpy as np
import plotly.express as px

# %%
states = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
CLIENT_ID = "qpTmdgMQYrqLy2gjZ5BdVOoJiIEqtebaxrNCKhq1NWDTQizBJc"
CLIENT_SECRET = "6XmxIyvmAgZ9teC2AeJithx0qH0lnnaETrgkXPQb"
# token_json = !curl -d "grant_type=client_credentials&client_id={CLIENT_ID}&client_secret={CLIENT_SECRET}" https://api.petfinder.com/v2/oauth2/token

# %%
CLIENT_ID = "6V6qjgwiK6c8fz66nBrhwNqlMtUURhuLqMxfhbS20O9KcWt4vG"
CLIENT_SECRET = "SbLL3KPrnHjnlWaldOxNVk9CEgUN9Y5Jijh8SB5y"

# %%
6V6qjgwiK6c8fz66nBrhwNqlMtUURhuLqMxfhbS20O9KcWt4vG

# %%
in_val = {'grant_type': 'client_credentials', 'client_id': CLIENT_ID, 'client_secret': CLIENT_SECRET}
url = "https://api.petfinder.com/v2/oauth2/token"
res = requests.post(url, data=in_val)
# res.status_code
ACCESS_TOKEN = res.json()['access_token']
# ACCESS_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..XT6THra8P6scb1l083ykPuMvJ4PXbUsQm0fUXvE5wPCWRnMx5ux0WXYGx6A1v5fwMYH75GDnz_gfmUFI8nmzrgK3LoF9lTinLNTteTcQqV26z0MBrdFi2Eld93YZZSV6nH0tdtaqdpG-aoqWbz0RCjBTIf347DPDMjCHdm0O28tjJXs2Ch7bNv_89wjZ0qdW-wEmJEvv4BD7lZhd7VqmOU2EmBlDs3OnJq0NtNJnFyf90rYbxMEGwo1hst_V41X7ONYTf88Wws43nY4POtyuScK0Rt3Pzl83-BcaVM__hJ8x_p3Z0MJqBDhj9tsg4dJy_FEO2h2a5nCM5PGu5_bf-w"

# %%
# payload={'type':"cat","breeds":"",'location':'NJ'}
url = "https://api.petfinder.com/v2/types/cat/breeds"
header = {"Authorization": f"Bearer {ACCESS_TOKEN}"}
response = requests.get(url, headers = header)
types=response.json()['breeds']
cat_breeds = [t['name'] for t in types]

# %%
url = "https://api.petfinder.com/v2/animals"
cat_breed_count = {}
for loc in states:
    #for b in cat_breeds:
    payload={'type':"Cat","breed":'Domestic Short Hair','location':loc}
    response = requests.get(url, headers = header,params=payload)
    cat_breed_count[loc]=response.json()['pagination']['total_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-0c442bf1d0da> in <module>
#       5     payload={'type':"Cat","breed":'Domestic Short Hair','location':loc}
#       6     response = requests.get(url, headers = header,params=payload)
# ----> 7     cat_breed_count[loc]=response.json()['pagination']['total_count']
#
# KeyError: 'pagination'

# %%
cat_breed_count
# Out:
# {'AK': 1,
#  'AL': 350,
#  'AR': 179,
#  'AZ': 577,
#  'CA': 470,
#  'CO': 537,
#  'CT': 4729,
#  'DC': 3580,
#  'DE': 4627,
#  'FL': 1809,
#  'GA': 1036,
#  'HI': 79,
#  'IA': 796,
#  'ID': 40,
#  'IL': 1030,
#  'IN': 1704,
#  'KS': 246,
#  'KY': 1288,
#  'LA': 315,
#  'MA': 888,
#  'MD': 3818,
#  'ME': 124,
#  'MI': 1153,
#  'MN': 739,
#  'MO': 494,
#  'MS': 107,
#  'MT': 59,
#  'NC': 1993,
#  'ND': 168,
#  'NE': 79,
#  'NH': 565,
#  'NJ': 7788,
#  'NM': 347,
#  'NV': 0,
#  'NY': 906,
#  'OH': 1846,
#  'OK': 418,
#  'OR': 18,
#  'PA': 4693,
#  'RI': 1382,
#  'SC': 1058,
#  'SD': 3,
#  'TN': 1062,
#  'TX': 234,
#  'UT': 310,
#  'VA': 2123,
#  'VT': 414,
#  'WA': 386,
#  'WI': 522,
#  'WV': 682,
#  'WY': 30}

# %%
df['text']
# Out:
# 0        AK<br>Count 1
# 1      AL<br>Count 350
# 2      AR<br>Count 179
# 3      AZ<br>Count 577
# 4      CA<br>Count 470
# 5      CO<br>Count 537
# 6     CT<br>Count 4729
# 7     DC<br>Count 3580
# 8     DE<br>Count 4627
# 9     FL<br>Count 1809
# 10    GA<br>Count 1036
# 11      HI<br>Count 79
# 12     IA<br>Count 796
# 13      ID<br>Count 40
# 14    IL<br>Count 1030
# 15    IN<br>Count 1704
# 16     KS<br>Count 246
# 17    KY<br>Count 1288
# 18     LA<br>Count 315
# 19     MA<br>Count 888
# 20    MD<br>Count 3818
# 21     ME<br>Count 124
# 22    MI<br>Count 1153
# 23     MN<br>Count 739
# 24     MO<br>Count 494
# 25     MS<br>Count 107
# 26      MT<br>Count 59
# 27    NC<br>Count 1993
# 28     ND<br>Count 168
# 29      NE<br>Count 79
# 30     NH<br>Count 565
# 31    NJ<br>Count 7788
# 32     NM<br>Count 347
# 33       NV<br>Count 0
# 34     NY<br>Count 906
# 35    OH<br>Count 1846
# 36     OK<br>Count 418
# 37      OR<br>Count 18
# 38    PA<br>Count 4693
# 39    RI<br>Count 1382
# 40    SC<br>Count 1058
# 41       SD<br>Count 3
# 42    TN<br>Count 1062
# 43     TX<br>Count 234
# 44     UT<br>Count 310
# 45    VA<br>Count 2123
# 46     VT<br>Count 414
# 47     WA<br>Count 386
# 48     WI<br>Count 522
# 49     WV<br>Count 682
# 50      WY<br>Count 30
# Name: text, dtype: object

# %%
url = "https://api.petfinder.com/v2/animals"
total_cat = {}
for s in states:
    total_cat[s] = {}
for loc in states:
    for b in cat_breeds:
        payload={'type':"Cat","breed":b,'location':loc}
        response = requests.get(url, headers = header,params=payload)
        total_cat[loc][b]=response.json()['pagination']['total_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-dd05d954bd0b> in <module>
#       7         payload={'type':"Cat","breed":b,'location':loc}
#       8         response = requests.get(url, headers = header,params=payload)
# ----> 9         total_cat[loc][b]=response.json()['pagination']['total_count']
#
# KeyError: 'pagination'

# %%
total_cat
# Out:
# {'AK': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 0,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 1,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 0,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 0,
#   'Domestic Long Hair': 0,
#   'Domestic Medium Hair': 0,
#   'Domestic Short Hair': 1,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 0,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 0,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 0,
#   'Tortoiseshell': 0,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 0,
#   'York Chocolate': 0},
#  'AL': {'Abyssinian': 0,
#   'American Bobtail': 2,
#   'American Curl': 0,
#   'American Shorthair': 82,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 1,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 2,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 0,
#   'Domestic Long Hair': 4,
#   'Domestic Medium Hair': 35,
#   'Domestic Short Hair': 348,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 1,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 1,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 8,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 27,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 1,
#   'Tortoiseshell': 3,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 3,
#   'York Chocolate': 0},
#  'AR': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 3,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 0,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 1,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 1,
#   'Domestic Long Hair': 11,
#   'Domestic Medium Hair': 7,
#   'Domestic Short Hair': 181,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 1,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 2,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 13,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 1,
#   'Tortoiseshell': 2,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 1,
#   'Tuxedo': 7,
#   'York Chocolate': 0},
#  'AZ': {'Abyssinian': 2,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 11,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 7,
#   'Birman': 0,
#   'Bombay': 7,
#   'British Shorthair': 1,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 16,
#   'Canadian Hairless': 0,
#   'Chartreux': 1,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 3,
#   'Dilute Tortoiseshell': 2,
#   'Domestic Long Hair': 57,
#   'Domestic Medium Hair': 93,
#   'Domestic Short Hair': 576,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 1,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 8,
#   'Manx': 1,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 4,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 2,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 13,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 18,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 4,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 125,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 9,
#   'Tortoiseshell': 16,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 4,
#   'Tuxedo': 31,
#   'York Chocolate': 0},
#  'CA': {'Abyssinian': 0,
#   'American Bobtail': 2,
#   'American Curl': 0,
#   'American Shorthair': 13,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 1,
#   'Birman': 0,
#   'Bombay': 3,
#   'British Shorthair': 1,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 28,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 1,
#   'Dilute Tortoiseshell': 6,
#   'Domestic Long Hair': 24,
#   'Domestic Medium Hair': 53,
#   'Domestic Short Hair': 475,
#   'Egyptian Mau': 1,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 1,
#   'Havana': 0,
#   'Himalayan': 2,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 14,
#   'Manx': 6,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 2,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 1,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 4,
#   'Scottish Fold': 1,
#   'Selkirk Rex': 0,
#   'Siamese': 36,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 1,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 105,
#   'Tiger': 5,
#   'Tonkinese': 0,
#   'Torbie': 3,
#   'Tortoiseshell': 18,
#   'Toyger': 0,
#   'Turkish Angora': 1,
#   'Turkish Van': 0,
#   'Tuxedo': 19,
#   'York Chocolate': 0},
#  'CO': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 1,
#   'American Shorthair': 4,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 3,
#   'Birman': 0,
#   'Bombay': 1,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 10,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 1,
#   'Dilute Tortoiseshell': 1,
#   'Domestic Long Hair': 60,
#   'Domestic Medium Hair': 69,
#   'Domestic Short Hair': 530,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 1,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 2,
#   'Munchkin': 0,
#   'Nebelung': 1,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 12,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 3,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 38,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 2,
#   'Tortoiseshell': 4,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 10,
#   'York Chocolate': 0},
#  'CT': {'Abyssinian': 8,
#   'American Bobtail': 9,
#   'American Curl': 1,
#   'American Shorthair': 201,
#   'American Wirehair': 0,
#   'Applehead Siamese': 1,
#   'Balinese': 0,
#   'Bengal': 30,
#   'Birman': 1,
#   'Bombay': 33,
#   'British Shorthair': 4,
#   'Burmese': 7,
#   'Burmilla': 0,
#   'Calico': 106,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 1,
#   'Dilute Calico': 18,
#   'Dilute Tortoiseshell': 12,
#   'Domestic Long Hair': 224,
#   'Domestic Medium Hair': 229,
#   'Domestic Short Hair': 4734,
#   'Egyptian Mau': 41,
#   'Exotic Shorthair': 3,
#   'Extra-Toes Cat / Hemingway Polydactyl': 14,
#   'Havana': 1,
#   'Himalayan': 5,
#   'Japanese Bobtail': 1,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 26,
#   'Manx': 7,
#   'Munchkin': 4,
#   'Nebelung': 1,
#   'Norwegian Forest Cat': 1,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 6,
#   'Oriental Tabby': 0,
#   'Persian': 21,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 5,
#   'Russian Blue': 29,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 27,
#   'Siberian': 5,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 3,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 382,
#   'Tiger': 75,
#   'Tonkinese': 0,
#   'Torbie': 18,
#   'Tortoiseshell': 67,
#   'Toyger': 0,
#   'Turkish Angora': 4,
#   'Turkish Van': 15,
#   'Tuxedo': 241,
#   'York Chocolate': 0},
#  'DC': {'Abyssinian': 2,
#   'American Bobtail': 5,
#   'American Curl': 1,
#   'American Shorthair': 59,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 6,
#   'Birman': 1,
#   'Bombay': 11,
#   'British Shorthair': 8,
#   'Burmese': 1,
#   'Burmilla': 0,
#   'Calico': 59,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 21,
#   'Dilute Tortoiseshell': 21,
#   'Domestic Long Hair': 156,
#   'Domestic Medium Hair': 159,
#   'Domestic Short Hair': 3591,
#   'Egyptian Mau': 3,
#   'Exotic Shorthair': 8,
#   'Extra-Toes Cat / Hemingway Polydactyl': 3,
#   'Havana': 0,
#   'Himalayan': 2,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 38,
#   'Manx': 9,
#   'Munchkin': 1,
#   'Nebelung': 1,
#   'Norwegian Forest Cat': 3,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 7,
#   'Oriental Tabby': 0,
#   'Persian': 19,
#   'Pixiebob': 1,
#   'Ragamuffin': 1,
#   'Ragdoll': 1,
#   'Russian Blue': 18,
#   'Scottish Fold': 4,
#   'Selkirk Rex': 0,
#   'Siamese': 44,
#   'Siberian': 0,
#   'Silver': 1,
#   'Singapura': 0,
#   'Snowshoe': 7,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 1,
#   'Tabby': 307,
#   'Tiger': 8,
#   'Tonkinese': 1,
#   'Torbie': 9,
#   'Tortoiseshell': 43,
#   'Toyger': 0,
#   'Turkish Angora': 3,
#   'Turkish Van': 3,
#   'Tuxedo': 87,
#   'York Chocolate': 0},
#  'DE': {'Abyssinian': 4,
#   'American Bobtail': 5,
#   'American Curl': 1,
#   'American Shorthair': 82,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 12,
#   'Birman': 1,
#   'Bombay': 9,
#   'British Shorthair': 10,
#   'Burmese': 1,
#   'Burmilla': 0,
#   'Calico': 100,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 26,
#   'Dilute Tortoiseshell': 30,
#   'Domestic Long Hair': 172,
#   'Domestic Medium Hair': 193,
#   'Domestic Short Hair': 4624,
#   'Egyptian Mau': 3,
#   'Exotic Shorthair': 6,
#   'Extra-Toes Cat / Hemingway Polydactyl': 5,
#   'Havana': 1,
#   'Himalayan': 2,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 57,
#   'Manx': 11,
#   'Munchkin': 1,
#   'Nebelung': 3,
#   'Norwegian Forest Cat': 6,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 5,
#   'Oriental Tabby': 0,
#   'Persian': 19,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 22,
#   'Scottish Fold': 5,
#   'Selkirk Rex': 0,
#   'Siamese': 43,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 8,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 1,
#   'Tabby': 404,
#   'Tiger': 15,
#   'Tonkinese': 1,
#   'Torbie': 14,
#   'Tortoiseshell': 60,
#   'Toyger': 0,
#   'Turkish Angora': 2,
#   'Turkish Van': 3,
#   'Tuxedo': 119,
#   'York Chocolate': 0},
#  'FL': {'Abyssinian': 7,
#   'American Bobtail': 7,
#   'American Curl': 1,
#   'American Shorthair': 70,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 29,
#   'Birman': 0,
#   'Bombay': 11,
#   'British Shorthair': 4,
#   'Burmese': 1,
#   'Burmilla': 0,
#   'Calico': 39,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 1,
#   'Dilute Calico': 4,
#   'Dilute Tortoiseshell': 5,
#   'Domestic Long Hair': 55,
#   'Domestic Medium Hair': 87,
#   'Domestic Short Hair': 1807,
#   'Egyptian Mau': 2,
#   'Exotic Shorthair': 2,
#   'Extra-Toes Cat / Hemingway Polydactyl': 11,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 38,
#   'Manx': 8,
#   'Munchkin': 4,
#   'Nebelung': 2,
#   'Norwegian Forest Cat': 2,
#   'Ocicat': 0,
#   'Oriental Long Hair': 1,
#   'Oriental Short Hair': 2,
#   'Oriental Tabby': 0,
#   'Persian': 2,
#   'Pixiebob': 0,
#   'Ragamuffin': 1,
#   'Ragdoll': 4,
#   'Russian Blue': 25,
#   'Scottish Fold': 1,
#   'Selkirk Rex': 1,
#   'Siamese': 51,
#   'Siberian': 0,
#   'Silver': 1,
#   'Singapura': 0,
#   'Snowshoe': 4,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 1,
#   'Tabby': 148,
#   'Tiger': 19,
#   'Tonkinese': 0,
#   'Torbie': 13,
#   'Tortoiseshell': 26,
#   'Toyger': 0,
#   'Turkish Angora': 5,
#   'Turkish Van': 0,
#   'Tuxedo': 58,
#   'York Chocolate': 0},
#  'GA': {'Abyssinian': 8,
#   'American Bobtail': 14,
#   'American Curl': 0,
#   'American Shorthair': 40,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 1,
#   'Birman': 0,
#   'Bombay': 15,
#   'British Shorthair': 2,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 37,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 9,
#   'Dilute Tortoiseshell': 5,
#   'Domestic Long Hair': 62,
#   'Domestic Medium Hair': 86,
#   'Domestic Short Hair': 1028,
#   'Egyptian Mau': 1,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 4,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 8,
#   'Manx': 6,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 3,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 4,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 8,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 9,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 1,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 186,
#   'Tiger': 3,
#   'Tonkinese': 0,
#   'Torbie': 5,
#   'Tortoiseshell': 18,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 3,
#   'Tuxedo': 34,
#   'York Chocolate': 0},
#  'HI': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 3,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 2,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 1,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 0,
#   'Domestic Long Hair': 2,
#   'Domestic Medium Hair': 9,
#   'Domestic Short Hair': 78,
#   'Egyptian Mau': 1,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 1,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 0,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 7,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 0,
#   'Tortoiseshell': 3,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 2,
#   'York Chocolate': 0},
#  'IA': {'Abyssinian': 1,
#   'American Bobtail': 1,
#   'American Curl': 0,
#   'American Shorthair': 4,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 1,
#   'British Shorthair': 1,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 8,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 6,
#   'Dilute Tortoiseshell': 4,
#   'Domestic Long Hair': 34,
#   'Domestic Medium Hair': 50,
#   'Domestic Short Hair': 794,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 2,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 1,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 1,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 1,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 2,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 56,
#   'Tiger': 2,
#   'Tonkinese': 0,
#   'Torbie': 6,
#   'Tortoiseshell': 4,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 12,
#   'York Chocolate': 0},
#  'ID': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 0,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 0,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 0,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 1,
#   'Dilute Tortoiseshell': 0,
#   'Domestic Long Hair': 4,
#   'Domestic Medium Hair': 3,
#   'Domestic Short Hair': 40,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 3,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 2,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 4,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 0,
#   'Tortoiseshell': 1,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 0,
#   'York Chocolate': 0},
#  'IL': {'Abyssinian': 0,
#   'American Bobtail': 2,
#   'American Curl': 0,
#   'American Shorthair': 12,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 3,
#   'Birman': 0,
#   'Bombay': 1,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 16,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 7,
#   'Dilute Tortoiseshell': 4,
#   'Domestic Long Hair': 61,
#   'Domestic Medium Hair': 90,
#   'Domestic Short Hair': 1029,
#   'Egyptian Mau': 1,
#   'Exotic Shorthair': 1,
#   'Extra-Toes Cat / Hemingway Polydactyl': 5,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 3,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 1,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 9,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 81,
#   'Tiger': 7,
#   'Tonkinese': 0,
#   'Torbie': 5,
#   'Tortoiseshell': 25,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 13,
#   'York Chocolate': 0},
#  'IN': {'Abyssinian': 4,
#   'American Bobtail': 1,
#   'American Curl': 0,
#   'American Shorthair': 34,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 5,
#   'British Shorthair': 0,
#   'Burmese': 1,
#   'Burmilla': 0,
#   'Calico': 32,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 9,
#   'Dilute Tortoiseshell': 2,
#   'Domestic Long Hair': 72,
#   'Domestic Medium Hair': 80,
#   'Domestic Short Hair': 1708,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 2,
#   'Extra-Toes Cat / Hemingway Polydactyl': 9,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 8,
#   'Manx': 4,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 11,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 21,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 3,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 92,
#   'Tiger': 20,
#   'Tonkinese': 0,
#   'Torbie': 5,
#   'Tortoiseshell': 31,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 2,
#   'Tuxedo': 28,
#   'York Chocolate': 0},
#  'KS': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 4,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 0,
#   'Birman': 0,
#   'Bombay': 0,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 0,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 3,
#   'Dilute Tortoiseshell': 1,
#   'Domestic Long Hair': 8,
#   'Domestic Medium Hair': 20,
#   'Domestic Short Hair': 248,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 0,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 2,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 4,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 1,
#   'Tiger': 0,
#   'Tonkinese': 0,
#   'Torbie': 1,
#   'Tortoiseshell': 1,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 0,
#   'York Chocolate': 0},
#  'KY': {'Abyssinian': 6,
#   'American Bobtail': 16,
#   'American Curl': 0,
#   'American Shorthair': 21,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 1,
#   'Bengal': 2,
#   'Birman': 0,
#   'Bombay': 7,
#   'British Shorthair': 0,
#   'Burmese': 9,
#   'Burmilla': 0,
#   'Calico': 38,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 17,
#   'Dilute Tortoiseshell': 16,
#   'Domestic Long Hair': 75,
#   'Domestic Medium Hair': 95,
#   'Domestic Short Hair': 1283,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 1,
#   'Extra-Toes Cat / Hemingway Polydactyl': 12,
#   'Havana': 0,
#   'Himalayan': 2,
#   'Japanese Bobtail': 2,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 37,
#   'Manx': 26,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 1,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 24,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 15,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 4,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 251,
#   'Tiger': 31,
#   'Tonkinese': 0,
#   'Torbie': 20,
#   'Tortoiseshell': 42,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 2,
#   'Tuxedo': 32,
#   'York Chocolate': 0},
#  'LA': {'Abyssinian': 0,
#   'American Bobtail': 5,
#   'American Curl': 0,
#   'American Shorthair': 5,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 1,
#   'Birman': 0,
#   'Bombay': 0,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 11,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 1,
#   'Domestic Long Hair': 16,
#   'Domestic Medium Hair': 30,
#   'Domestic Short Hair': 316,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 1,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 0,
#   'Manx': 2,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 2,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 7,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 2,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 41,
#   'Tiger': 1,
#   'Tonkinese': 0,
#   'Torbie': 2,
#   'Tortoiseshell': 5,
#   'Toyger': 0,
#   'Turkish Angora': 0,
#   'Turkish Van': 0,
#   'Tuxedo': 3,
#   'York Chocolate': 0},
#  'MA': {'Abyssinian': 2,
#   'American Bobtail': 1,
#   'American Curl': 0,
#   'American Shorthair': 21,
#   'American Wirehair': 0,
#   'Applehead Siamese': 1,
#   'Balinese': 0,
#   'Bengal': 3,
#   'Birman': 0,
#   'Bombay': 7,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 16,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 5,
#   'Domestic Long Hair': 77,
#   'Domestic Medium Hair': 64,
#   'Domestic Short Hair': 895,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 1,
#   'Havana': 0,
#   'Himalayan': 2,
#   'Japanese Bobtail': 1,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 7,
#   'Manx': 0,
#   'Munchkin': 1,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 2,
#   'Oriental Tabby': 0,
#   'Persian': 2,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 1,
#   'Russian Blue': 5,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 15,
#   'Siberian': 1,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 3,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 47,
#   'Tiger': 21,
#   'Tonkinese': 0,
#   'Torbie': 4,
#   'Tortoiseshell': 16,
#   'Toyger': 0,
#   'Turkish Angora': 1,
#   'Turkish Van': 1,
#   'Tuxedo': 43,
#   'York Chocolate': 0},
#  'MD': {'Abyssinian': 3,
#   'American Bobtail': 5,
#   'American Curl': 1,
#   'American Shorthair': 62,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 6,
#   'Birman': 1,
#   'Bombay': 11,
#   'British Shorthair': 8,
#   'Burmese': 1,
#   'Burmilla': 0,
#   'Calico': 61,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 22,
#   'Dilute Tortoiseshell': 21,
#   'Domestic Long Hair': 152,
#   'Domestic Medium Hair': 163,
#   'Domestic Short Hair': 3830,
#   'Egyptian Mau': 3,
#   'Exotic Shorthair': 8,
#   'Extra-Toes Cat / Hemingway Polydactyl': 4,
#   'Havana': 0,
#   'Himalayan': 2,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 35,
#   'Manx': 9,
#   'Munchkin': 1,
#   'Nebelung': 2,
#   'Norwegian Forest Cat': 3,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 7,
#   'Oriental Tabby': 0,
#   'Persian': 18,
#   'Pixiebob': 1,
#   'Ragamuffin': 1,
#   'Ragdoll': 1,
#   'Russian Blue': 17,
#   'Scottish Fold': 4,
#   'Selkirk Rex': 0,
#   'Siamese': 39,
#   'Siberian': 0,
#   'Silver': 1,
#   'Singapura': 0,
#   'Snowshoe': 7,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 1,
#   'Tabby': 322,
#   'Tiger': 9,
#   'Tonkinese': 1,
#   'Torbie': 9,
#   'Tortoiseshell': 45,
#   'Toyger': 0,
#   'Turkish Angora': 3,
#   'Turkish Van': 3,
#   'Tuxedo': 89,
#   'York Chocolate': 0},
#  'ME': {'Abyssinian': 0,
#   'American Bobtail': 0,
#   'American Curl': 0,
#   'American Shorthair': 1,
#   'American Wirehair': 0,
#   'Applehead Siamese': 0,
#   'Balinese': 0,
#   'Bengal': 1,
#   'Birman': 0,
#   'Bombay': 0,
#   'British Shorthair': 0,
#   'Burmese': 0,
#   'Burmilla': 0,
#   'Calico': 0,
#   'Canadian Hairless': 0,
#   'Chartreux': 0,
#   'Chausie': 0,
#   'Chinchilla': 0,
#   'Cornish Rex': 0,
#   'Cymric': 0,
#   'Devon Rex': 0,
#   'Dilute Calico': 0,
#   'Dilute Tortoiseshell': 1,
#   'Domestic Long Hair': 11,
#   'Domestic Medium Hair': 8,
#   'Domestic Short Hair': 124,
#   'Egyptian Mau': 0,
#   'Exotic Shorthair': 0,
#   'Extra-Toes Cat / Hemingway Polydactyl': 0,
#   'Havana': 0,
#   'Himalayan': 1,
#   'Japanese Bobtail': 0,
#   'Javanese': 0,
#   'Korat': 0,
#   'LaPerm': 0,
#   'Maine Coon': 1,
#   'Manx': 0,
#   'Munchkin': 0,
#   'Nebelung': 0,
#   'Norwegian Forest Cat': 0,
#   'Ocicat': 0,
#   'Oriental Long Hair': 0,
#   'Oriental Short Hair': 0,
#   'Oriental Tabby': 0,
#   'Persian': 0,
#   'Pixiebob': 0,
#   'Ragamuffin': 0,
#   'Ragdoll': 0,
#   'Russian Blue': 0,
#   'Scottish Fold': 0,
#   'Selkirk Rex': 0,
#   'Siamese': 0,
#   'Siberian': 0,
#   'Silver': 0,
#   'Singapura': 0,
#   'Snowshoe': 0,
#   'Somali': 0,
#   'Sphynx / Hairless Cat': 0,
#   'Tabby': 1},
#  'MI': {},
#  'MN': {},
#  'MO': {},
#  'MS': {},
#  'MT': {},
#  'NC': {},
#  'ND': {},
#  'NE': {},
#  'NH': {},
#  'NJ': {},
#  'NM': {},
#  'NV': {},
#  'NY': {},
#  'OH': {},
#  'OK': {},
#  'OR': {},
#  'PA': {},
#  'RI': {},
#  'SC': {},
#  'SD': {},
#  'TN': {},
#  'TX': {},
#  'UT': {},
#  'VA': {},
#  'VT': {},
#  'WA': {},
#  'WI': {},
#  'WV': {},
#  'WY': {}}

# %%
sorted_cat = {}
for s in states:
    #print(total_cat[s].items())
    sorted_cat[s] = sorted(total_cat[s].items(), key=lambda x:x[1], reverse = True)
sorted_cat
# Out:
# {'AK': [('Bombay', 1),
#   ('Domestic Short Hair', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Domestic Long Hair', 0),
#   ('Domestic Medium Hair', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tabby', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Tortoiseshell', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'AL': [('Domestic Short Hair', 348),
#   ('American Shorthair', 82),
#   ('Domestic Medium Hair', 35),
#   ('Tabby', 27),
#   ('Siamese', 8),
#   ('Domestic Long Hair', 4),
#   ('Tortoiseshell', 3),
#   ('Tuxedo', 3),
#   ('American Bobtail', 2),
#   ('Calico', 2),
#   ('Bombay', 1),
#   ('Manx', 1),
#   ('Russian Blue', 1),
#   ('Torbie', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'AR': [('Domestic Short Hair', 181),
#   ('Tabby', 13),
#   ('Domestic Long Hair', 11),
#   ('Domestic Medium Hair', 7),
#   ('Tuxedo', 7),
#   ('American Shorthair', 3),
#   ('Siamese', 2),
#   ('Tortoiseshell', 2),
#   ('Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Persian', 1),
#   ('Russian Blue', 1),
#   ('Torbie', 1),
#   ('Turkish Van', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'AZ': [('Domestic Short Hair', 576),
#   ('Tabby', 125),
#   ('Domestic Medium Hair', 93),
#   ('Domestic Long Hair', 57),
#   ('Tuxedo', 31),
#   ('Siamese', 18),
#   ('Calico', 16),
#   ('Tortoiseshell', 16),
#   ('Russian Blue', 13),
#   ('American Shorthair', 11),
#   ('Torbie', 9),
#   ('Maine Coon', 8),
#   ('Bengal', 7),
#   ('Bombay', 7),
#   ('Norwegian Forest Cat', 4),
#   ('Snowshoe', 4),
#   ('Turkish Van', 4),
#   ('Dilute Calico', 3),
#   ('Abyssinian', 2),
#   ('Dilute Tortoiseshell', 2),
#   ('Oriental Short Hair', 2),
#   ('British Shorthair', 1),
#   ('Chartreux', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Manx', 1),
#   ('Persian', 1),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'CA': [('Domestic Short Hair', 475),
#   ('Tabby', 105),
#   ('Domestic Medium Hair', 53),
#   ('Siamese', 36),
#   ('Calico', 28),
#   ('Domestic Long Hair', 24),
#   ('Tuxedo', 19),
#   ('Tortoiseshell', 18),
#   ('Maine Coon', 14),
#   ('American Shorthair', 13),
#   ('Dilute Tortoiseshell', 6),
#   ('Manx', 6),
#   ('Tiger', 5),
#   ('Russian Blue', 4),
#   ('Bombay', 3),
#   ('Torbie', 3),
#   ('American Bobtail', 2),
#   ('Himalayan', 2),
#   ('Norwegian Forest Cat', 2),
#   ('Bengal', 1),
#   ('British Shorthair', 1),
#   ('Dilute Calico', 1),
#   ('Egyptian Mau', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Oriental Short Hair', 1),
#   ('Ragdoll', 1),
#   ('Scottish Fold', 1),
#   ('Snowshoe', 1),
#   ('Turkish Angora', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'CO': [('Domestic Short Hair', 530),
#   ('Domestic Medium Hair', 69),
#   ('Domestic Long Hair', 60),
#   ('Tabby', 38),
#   ('Siamese', 12),
#   ('Calico', 10),
#   ('Tuxedo', 10),
#   ('American Shorthair', 4),
#   ('Tortoiseshell', 4),
#   ('Bengal', 3),
#   ('Snowshoe', 3),
#   ('Manx', 2),
#   ('Torbie', 2),
#   ('American Curl', 1),
#   ('Bombay', 1),
#   ('Dilute Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Japanese Bobtail', 1),
#   ('Nebelung', 1),
#   ('Persian', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'CT': [('Domestic Short Hair', 4734),
#   ('Tabby', 382),
#   ('Tuxedo', 241),
#   ('Domestic Medium Hair', 229),
#   ('Domestic Long Hair', 224),
#   ('American Shorthair', 201),
#   ('Calico', 106),
#   ('Tiger', 75),
#   ('Tortoiseshell', 67),
#   ('Egyptian Mau', 41),
#   ('Bombay', 33),
#   ('Bengal', 30),
#   ('Russian Blue', 29),
#   ('Siamese', 27),
#   ('Maine Coon', 26),
#   ('Persian', 21),
#   ('Dilute Calico', 18),
#   ('Torbie', 18),
#   ('Turkish Van', 15),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 14),
#   ('Dilute Tortoiseshell', 12),
#   ('American Bobtail', 9),
#   ('Abyssinian', 8),
#   ('Burmese', 7),
#   ('Manx', 7),
#   ('Oriental Short Hair', 6),
#   ('Himalayan', 5),
#   ('Ragdoll', 5),
#   ('Siberian', 5),
#   ('British Shorthair', 4),
#   ('Munchkin', 4),
#   ('Turkish Angora', 4),
#   ('Exotic Shorthair', 3),
#   ('Snowshoe', 3),
#   ('American Curl', 1),
#   ('Applehead Siamese', 1),
#   ('Birman', 1),
#   ('Devon Rex', 1),
#   ('Havana', 1),
#   ('Japanese Bobtail', 1),
#   ('Nebelung', 1),
#   ('Norwegian Forest Cat', 1),
#   ('American Wirehair', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'DC': [('Domestic Short Hair', 3591),
#   ('Tabby', 307),
#   ('Domestic Medium Hair', 159),
#   ('Domestic Long Hair', 156),
#   ('Tuxedo', 87),
#   ('American Shorthair', 59),
#   ('Calico', 59),
#   ('Siamese', 44),
#   ('Tortoiseshell', 43),
#   ('Maine Coon', 38),
#   ('Dilute Calico', 21),
#   ('Dilute Tortoiseshell', 21),
#   ('Persian', 19),
#   ('Russian Blue', 18),
#   ('Bombay', 11),
#   ('Manx', 9),
#   ('Torbie', 9),
#   ('British Shorthair', 8),
#   ('Exotic Shorthair', 8),
#   ('Tiger', 8),
#   ('Oriental Short Hair', 7),
#   ('Snowshoe', 7),
#   ('Bengal', 6),
#   ('American Bobtail', 5),
#   ('Scottish Fold', 4),
#   ('Egyptian Mau', 3),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 3),
#   ('Norwegian Forest Cat', 3),
#   ('Turkish Angora', 3),
#   ('Turkish Van', 3),
#   ('Abyssinian', 2),
#   ('Himalayan', 2),
#   ('American Curl', 1),
#   ('Birman', 1),
#   ('Burmese', 1),
#   ('Munchkin', 1),
#   ('Nebelung', 1),
#   ('Pixiebob', 1),
#   ('Ragamuffin', 1),
#   ('Ragdoll', 1),
#   ('Silver', 1),
#   ('Sphynx / Hairless Cat', 1),
#   ('Tonkinese', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'DE': [('Domestic Short Hair', 4624),
#   ('Tabby', 404),
#   ('Domestic Medium Hair', 193),
#   ('Domestic Long Hair', 172),
#   ('Tuxedo', 119),
#   ('Calico', 100),
#   ('American Shorthair', 82),
#   ('Tortoiseshell', 60),
#   ('Maine Coon', 57),
#   ('Siamese', 43),
#   ('Dilute Tortoiseshell', 30),
#   ('Dilute Calico', 26),
#   ('Russian Blue', 22),
#   ('Persian', 19),
#   ('Tiger', 15),
#   ('Torbie', 14),
#   ('Bengal', 12),
#   ('Manx', 11),
#   ('British Shorthair', 10),
#   ('Bombay', 9),
#   ('Snowshoe', 8),
#   ('Exotic Shorthair', 6),
#   ('Norwegian Forest Cat', 6),
#   ('American Bobtail', 5),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 5),
#   ('Oriental Short Hair', 5),
#   ('Scottish Fold', 5),
#   ('Abyssinian', 4),
#   ('Egyptian Mau', 3),
#   ('Nebelung', 3),
#   ('Turkish Van', 3),
#   ('Himalayan', 2),
#   ('Turkish Angora', 2),
#   ('American Curl', 1),
#   ('Birman', 1),
#   ('Burmese', 1),
#   ('Havana', 1),
#   ('Munchkin', 1),
#   ('Ragdoll', 1),
#   ('Sphynx / Hairless Cat', 1),
#   ('Tonkinese', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'FL': [('Domestic Short Hair', 1807),
#   ('Tabby', 148),
#   ('Domestic Medium Hair', 87),
#   ('American Shorthair', 70),
#   ('Tuxedo', 58),
#   ('Domestic Long Hair', 55),
#   ('Siamese', 51),
#   ('Calico', 39),
#   ('Maine Coon', 38),
#   ('Bengal', 29),
#   ('Tortoiseshell', 26),
#   ('Russian Blue', 25),
#   ('Tiger', 19),
#   ('Torbie', 13),
#   ('Bombay', 11),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 11),
#   ('Manx', 8),
#   ('Abyssinian', 7),
#   ('American Bobtail', 7),
#   ('Dilute Tortoiseshell', 5),
#   ('Turkish Angora', 5),
#   ('British Shorthair', 4),
#   ('Dilute Calico', 4),
#   ('Munchkin', 4),
#   ('Ragdoll', 4),
#   ('Snowshoe', 4),
#   ('Egyptian Mau', 2),
#   ('Exotic Shorthair', 2),
#   ('Nebelung', 2),
#   ('Norwegian Forest Cat', 2),
#   ('Oriental Short Hair', 2),
#   ('Persian', 2),
#   ('American Curl', 1),
#   ('Burmese', 1),
#   ('Devon Rex', 1),
#   ('Oriental Long Hair', 1),
#   ('Ragamuffin', 1),
#   ('Scottish Fold', 1),
#   ('Selkirk Rex', 1),
#   ('Silver', 1),
#   ('Sphynx / Hairless Cat', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'GA': [('Domestic Short Hair', 1028),
#   ('Tabby', 186),
#   ('Domestic Medium Hair', 86),
#   ('Domestic Long Hair', 62),
#   ('American Shorthair', 40),
#   ('Calico', 37),
#   ('Tuxedo', 34),
#   ('Tortoiseshell', 18),
#   ('Bombay', 15),
#   ('American Bobtail', 14),
#   ('Dilute Calico', 9),
#   ('Siamese', 9),
#   ('Abyssinian', 8),
#   ('Maine Coon', 8),
#   ('Russian Blue', 8),
#   ('Manx', 6),
#   ('Dilute Tortoiseshell', 5),
#   ('Torbie', 5),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 4),
#   ('Oriental Short Hair', 4),
#   ('Norwegian Forest Cat', 3),
#   ('Tiger', 3),
#   ('Turkish Van', 3),
#   ('British Shorthair', 2),
#   ('Bengal', 1),
#   ('Egyptian Mau', 1),
#   ('Persian', 1),
#   ('Snowshoe', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'HI': [('Domestic Short Hair', 78),
#   ('Domestic Medium Hair', 9),
#   ('Tabby', 7),
#   ('American Shorthair', 3),
#   ('Tortoiseshell', 3),
#   ('Bombay', 2),
#   ('Domestic Long Hair', 2),
#   ('Tuxedo', 2),
#   ('Calico', 1),
#   ('Egyptian Mau', 1),
#   ('Oriental Short Hair', 1),
#   ('Ragdoll', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'IA': [('Domestic Short Hair', 794),
#   ('Tabby', 56),
#   ('Domestic Medium Hair', 50),
#   ('Domestic Long Hair', 34),
#   ('Tuxedo', 12),
#   ('Calico', 8),
#   ('Dilute Calico', 6),
#   ('Torbie', 6),
#   ('American Shorthair', 4),
#   ('Dilute Tortoiseshell', 4),
#   ('Tortoiseshell', 4),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Siamese', 2),
#   ('Tiger', 2),
#   ('Abyssinian', 1),
#   ('American Bobtail', 1),
#   ('Bombay', 1),
#   ('British Shorthair', 1),
#   ('Manx', 1),
#   ('Oriental Short Hair', 1),
#   ('Ragdoll', 1),
#   ('Russian Blue', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'ID': [('Domestic Short Hair', 40),
#   ('Domestic Long Hair', 4),
#   ('Tabby', 4),
#   ('Domestic Medium Hair', 3),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 3),
#   ('Siamese', 2),
#   ('Dilute Calico', 1),
#   ('Tortoiseshell', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'IL': [('Domestic Short Hair', 1029),
#   ('Domestic Medium Hair', 90),
#   ('Tabby', 81),
#   ('Domestic Long Hair', 61),
#   ('Tortoiseshell', 25),
#   ('Calico', 16),
#   ('Tuxedo', 13),
#   ('American Shorthair', 12),
#   ('Siamese', 9),
#   ('Dilute Calico', 7),
#   ('Tiger', 7),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 5),
#   ('Torbie', 5),
#   ('Dilute Tortoiseshell', 4),
#   ('Bengal', 3),
#   ('Maine Coon', 3),
#   ('American Bobtail', 2),
#   ('Bombay', 1),
#   ('Egyptian Mau', 1),
#   ('Exotic Shorthair', 1),
#   ('Russian Blue', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'IN': [('Domestic Short Hair', 1708),
#   ('Tabby', 92),
#   ('Domestic Medium Hair', 80),
#   ('Domestic Long Hair', 72),
#   ('American Shorthair', 34),
#   ('Calico', 32),
#   ('Tortoiseshell', 31),
#   ('Tuxedo', 28),
#   ('Siamese', 21),
#   ('Tiger', 20),
#   ('Russian Blue', 11),
#   ('Dilute Calico', 9),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 9),
#   ('Maine Coon', 8),
#   ('Bombay', 5),
#   ('Torbie', 5),
#   ('Abyssinian', 4),
#   ('Manx', 4),
#   ('Snowshoe', 3),
#   ('Dilute Tortoiseshell', 2),
#   ('Exotic Shorthair', 2),
#   ('Turkish Van', 2),
#   ('American Bobtail', 1),
#   ('Burmese', 1),
#   ('Persian', 1),
#   ('Ragdoll', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'KS': [('Domestic Short Hair', 248),
#   ('Domestic Medium Hair', 20),
#   ('Domestic Long Hair', 8),
#   ('American Shorthair', 4),
#   ('Siamese', 4),
#   ('Dilute Calico', 3),
#   ('Manx', 2),
#   ('Dilute Tortoiseshell', 1),
#   ('Tabby', 1),
#   ('Torbie', 1),
#   ('Tortoiseshell', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'KY': [('Domestic Short Hair', 1283),
#   ('Tabby', 251),
#   ('Domestic Medium Hair', 95),
#   ('Domestic Long Hair', 75),
#   ('Tortoiseshell', 42),
#   ('Calico', 38),
#   ('Maine Coon', 37),
#   ('Tuxedo', 32),
#   ('Tiger', 31),
#   ('Manx', 26),
#   ('Russian Blue', 24),
#   ('American Shorthair', 21),
#   ('Torbie', 20),
#   ('Dilute Calico', 17),
#   ('American Bobtail', 16),
#   ('Dilute Tortoiseshell', 16),
#   ('Siamese', 15),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 12),
#   ('Burmese', 9),
#   ('Bombay', 7),
#   ('Abyssinian', 6),
#   ('Snowshoe', 4),
#   ('Bengal', 2),
#   ('Himalayan', 2),
#   ('Japanese Bobtail', 2),
#   ('Turkish Van', 2),
#   ('Balinese', 1),
#   ('Exotic Shorthair', 1),
#   ('Persian', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Havana', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'LA': [('Domestic Short Hair', 316),
#   ('Tabby', 41),
#   ('Domestic Medium Hair', 30),
#   ('Domestic Long Hair', 16),
#   ('Calico', 11),
#   ('Siamese', 7),
#   ('American Bobtail', 5),
#   ('American Shorthair', 5),
#   ('Tortoiseshell', 5),
#   ('Tuxedo', 3),
#   ('Manx', 2),
#   ('Russian Blue', 2),
#   ('Snowshoe', 2),
#   ('Torbie', 2),
#   ('Bengal', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Himalayan', 1),
#   ('Tiger', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'MA': [('Domestic Short Hair', 895),
#   ('Domestic Long Hair', 77),
#   ('Domestic Medium Hair', 64),
#   ('Tabby', 47),
#   ('Tuxedo', 43),
#   ('American Shorthair', 21),
#   ('Tiger', 21),
#   ('Calico', 16),
#   ('Tortoiseshell', 16),
#   ('Siamese', 15),
#   ('Bombay', 7),
#   ('Maine Coon', 7),
#   ('Dilute Tortoiseshell', 5),
#   ('Russian Blue', 5),
#   ('Torbie', 4),
#   ('Bengal', 3),
#   ('Snowshoe', 3),
#   ('Abyssinian', 2),
#   ('Himalayan', 2),
#   ('Oriental Short Hair', 2),
#   ('Persian', 2),
#   ('American Bobtail', 1),
#   ('Applehead Siamese', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Japanese Bobtail', 1),
#   ('Munchkin', 1),
#   ('Ragdoll', 1),
#   ('Siberian', 1),
#   ('Turkish Angora', 1),
#   ('Turkish Van', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'MD': [('Domestic Short Hair', 3830),
#   ('Tabby', 322),
#   ('Domestic Medium Hair', 163),
#   ('Domestic Long Hair', 152),
#   ('Tuxedo', 89),
#   ('American Shorthair', 62),
#   ('Calico', 61),
#   ('Tortoiseshell', 45),
#   ('Siamese', 39),
#   ('Maine Coon', 35),
#   ('Dilute Calico', 22),
#   ('Dilute Tortoiseshell', 21),
#   ('Persian', 18),
#   ('Russian Blue', 17),
#   ('Bombay', 11),
#   ('Manx', 9),
#   ('Tiger', 9),
#   ('Torbie', 9),
#   ('British Shorthair', 8),
#   ('Exotic Shorthair', 8),
#   ('Oriental Short Hair', 7),
#   ('Snowshoe', 7),
#   ('Bengal', 6),
#   ('American Bobtail', 5),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 4),
#   ('Scottish Fold', 4),
#   ('Abyssinian', 3),
#   ('Egyptian Mau', 3),
#   ('Norwegian Forest Cat', 3),
#   ('Turkish Angora', 3),
#   ('Turkish Van', 3),
#   ('Himalayan', 2),
#   ('Nebelung', 2),
#   ('American Curl', 1),
#   ('Birman', 1),
#   ('Burmese', 1),
#   ('Munchkin', 1),
#   ('Pixiebob', 1),
#   ('Ragamuffin', 1),
#   ('Ragdoll', 1),
#   ('Silver', 1),
#   ('Sphynx / Hairless Cat', 1),
#   ('Tonkinese', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'ME': [('Domestic Short Hair', 124),
#   ('Domestic Long Hair', 11),
#   ('Domestic Medium Hair', 8),
#   ('American Shorthair', 1),
#   ('Bengal', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Himalayan', 1),
#   ('Maine Coon', 1),
#   ('Tabby', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0)],
#  'MI': [],
#  'MN': [],
#  'MO': [],
#  'MS': [],
#  'MT': [],
#  'NC': [],
#  'ND': [],
#  'NE': [],
#  'NH': [],
#  'NJ': [],
#  'NM': [],
#  'NV': [],
#  'NY': [],
#  'OH': [],
#  'OK': [],
#  'OR': [],
#  'PA': [],
#  'RI': [],
#  'SC': [],
#  'SD': [],
#  'TN': [],
#  'TX': [],
#  'UT': [],
#  'VA': [],
#  'VT': [],
#  'WA': [],
#  'WI': [],
#  'WV': [],
#  'WY': []}

# %%
total_count_per_state = {}
for state in states:
    total = 0
    for k,v in sorted_cat[state]:
        total += v
    total_count_per_state[state] = total
total_count_per_state
# Out:
# {'AK': 2,
#  'AL': 518,
#  'AR': 232,
#  'AZ': 1013,
#  'CA': 828,
#  'CO': 754,
#  'CT': 6621,
#  'DC': 4734,
#  'DE': 6087,
#  'FL': 2560,
#  'GA': 1601,
#  'HI': 110,
#  'IA': 992,
#  'ID': 58,
#  'IL': 1376,
#  'IN': 2186,
#  'KS': 293,
#  'KY': 2088,
#  'LA': 451,
#  'MA': 1266,
#  'MD': 4992,
#  'ME': 149,
#  'MI': 0,
#  'MN': 0,
#  'MO': 0,
#  'MS': 0,
#  'MT': 0,
#  'NC': 0,
#  'ND': 0,
#  'NE': 0,
#  'NH': 0,
#  'NJ': 0,
#  'NM': 0,
#  'NV': 0,
#  'NY': 0,
#  'OH': 0,
#  'OK': 0,
#  'OR': 0,
#  'PA': 0,
#  'RI': 0,
#  'SC': 0,
#  'SD': 0,
#  'TN': 0,
#  'TX': 0,
#  'UT': 0,
#  'VA': 0,
#  'VT': 0,
#  'WA': 0,
#  'WI': 0,
#  'WV': 0,
#  'WY': 0}

# %%
top5_cat_per_states = {}
ranks = ['top1','top2','top3','top4','top5']
for r in ranks:
    top5_cat_per_states[r]=[]
for state in states:
    i=0
    for k,v in sorted_cat[state]:
        top5_cat_per_states[ranks[i]].append(k)
        i+=1
        if i==5: break

# %%
for r in ranks:
    l = len(top5_cat_per_states[r])
    for i in range(l,51):
        top5_cat_per_states[r].append(" ")

# %%
top5_cat_per_states
# Out:
# {'top1': ['Bombay',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  'top2': ['Domestic Short Hair',
#   'American Shorthair',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Tabby',
#   'Domestic Long Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  'top3': ['Abyssinian',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Tuxedo',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  'top4': ['American Bobtail',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Siamese',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'American Shorthair',
#   'Domestic Long Hair',
#   'American Shorthair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'American Shorthair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'American Shorthair',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' '],
#  'top5': ['American Curl',
#   'Siamese',
#   'Tuxedo',
#   'Tuxedo',
#   'Calico',
#   'Siamese',
#   'Domestic Long Hair',
#   'Tuxedo',
#   'Tuxedo',
#   'Tuxedo',
#   'American Shorthair',
#   'Tortoiseshell',
#   'Tuxedo',
#   'Extra-Toes Cat / Hemingway Polydactyl',
#   'Tortoiseshell',
#   'American Shorthair',
#   'Siamese',
#   'Tortoiseshell',
#   'Calico',
#   'Tuxedo',
#   'Tuxedo',
#   'Bengal',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ']}

# %% [markdown]
# Day2 Data

# %%
states2 = [ 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
url = "https://api.petfinder.com/v2/animals"
total_cat2 = {}
for s in states2:
    total_cat2[s] = {}
for loc in states2:
    for b in cat_breeds:
        payload={'type':"Cat","breed":b,'location':loc}
        response = requests.get(url, headers = header,params=payload)
        total_cat2[loc][b]=response.json()['pagination']['total_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a10e0f5a6d07> in <module>
#       7         payload={'type':"Cat","breed":b,'location':loc}
#       8         response = requests.get(url, headers = header,params=payload)
# ----> 9         total_cat2[loc][b]=response.json()['pagination']['total_count']
#
# KeyError: 'pagination'

# %%
sorted_cat2 = {}
for s in states2:
    #print(total_cat[s].items())
    sorted_cat2[s] = sorted(total_cat2[s].items(), key=lambda x:x[1], reverse = True)
sorted_cat2
# Out:
# {'ME': [('Domestic Short Hair', 121),
#   ('Domestic Long Hair', 11),
#   ('Domestic Medium Hair', 8),
#   ('Tuxedo', 3),
#   ('Bengal', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Himalayan', 1),
#   ('Maine Coon', 1),
#   ('Tabby', 1),
#   ('Tiger', 1),
#   ('Torbie', 1),
#   ('Tortoiseshell', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'MI': [('Domestic Short Hair', 1140),
#   ('Domestic Long Hair', 87),
#   ('Domestic Medium Hair', 68),
#   ('Tabby', 51),
#   ('American Shorthair', 18),
#   ('Tiger', 15),
#   ('Siamese', 13),
#   ('Calico', 11),
#   ('Tuxedo', 11),
#   ('Tortoiseshell', 9),
#   ('American Bobtail', 6),
#   ('Torbie', 6),
#   ('Dilute Tortoiseshell', 4),
#   ('Dilute Calico', 3),
#   ('Manx', 3),
#   ('Russian Blue', 3),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Maine Coon', 2),
#   ('Applehead Siamese', 1),
#   ('Bombay', 1),
#   ('Havana', 1),
#   ('Oriental Tabby', 1),
#   ('Persian', 1),
#   ('Siberian', 1),
#   ('Silver', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'MN': [('Domestic Short Hair', 786),
#   ('Tabby', 64),
#   ('Domestic Medium Hair', 61),
#   ('Domestic Long Hair', 57),
#   ('Tuxedo', 17),
#   ('Calico', 14),
#   ('Siamese', 11),
#   ('Tortoiseshell', 10),
#   ('American Shorthair', 4),
#   ('Dilute Calico', 4),
#   ('Tonkinese', 3),
#   ('Bengal', 2),
#   ('Dilute Tortoiseshell', 2),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Maine Coon', 2),
#   ('Manx', 2),
#   ('Ragdoll', 2),
#   ('Tiger', 2),
#   ('Torbie', 2),
#   ('Abyssinian', 1),
#   ('American Bobtail', 1),
#   ('American Curl', 1),
#   ('Oriental Short Hair', 1),
#   ('Turkish Van', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'MO': [('Domestic Short Hair', 496),
#   ('Tabby', 61),
#   ('Domestic Long Hair', 37),
#   ('Domestic Medium Hair', 26),
#   ('Siamese', 16),
#   ('Tuxedo', 13),
#   ('Calico', 11),
#   ('American Shorthair', 9),
#   ('Tortoiseshell', 8),
#   ('Turkish Van', 5),
#   ('Manx', 4),
#   ('Torbie', 4),
#   ('Dilute Calico', 3),
#   ('Russian Blue', 3),
#   ('American Bobtail', 2),
#   ('Dilute Tortoiseshell', 2),
#   ('Egyptian Mau', 2),
#   ('Bengal', 1),
#   ('Maine Coon', 1),
#   ('Persian', 1),
#   ('Tiger', 1),
#   ('Turkish Angora', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'MS': [('Domestic Short Hair', 106),
#   ('Tabby', 18),
#   ('Domestic Long Hair', 13),
#   ('American Shorthair', 12),
#   ('Domestic Medium Hair', 8),
#   ('Siamese', 6),
#   ('Maine Coon', 3),
#   ('Tortoiseshell', 3),
#   ('Calico', 1),
#   ('Dilute Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Torbie', 1),
#   ('Tuxedo', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'MT': [('Domestic Short Hair', 57),
#   ('Domestic Medium Hair', 12),
#   ('Domestic Long Hair', 10),
#   ('Scottish Fold', 1),
#   ('Tabby', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Tortoiseshell', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'NC': [('Domestic Short Hair', 1971),
#   ('Tabby', 175),
#   ('Domestic Medium Hair', 145),
#   ('Domestic Long Hair', 89),
#   ('Tuxedo', 53),
#   ('American Shorthair', 51),
#   ('Calico', 37),
#   ('Siamese', 35),
#   ('Tortoiseshell', 34),
#   ('Manx', 11),
#   ('American Bobtail', 8),
#   ('Dilute Tortoiseshell', 8),
#   ('Dilute Calico', 6),
#   ('Tiger', 6),
#   ('Torbie', 6),
#   ('Maine Coon', 4),
#   ('Russian Blue', 4),
#   ('Snowshoe', 3),
#   ('Abyssinian', 2),
#   ('Bombay', 2),
#   ('British Shorthair', 2),
#   ('Burmese', 2),
#   ('Cymric', 2),
#   ('Turkish Van', 2),
#   ('Bengal', 1),
#   ('Exotic Shorthair', 1),
#   ('Himalayan', 1),
#   ('Munchkin', 1),
#   ('Nebelung', 1),
#   ('Norwegian Forest Cat', 1),
#   ('Oriental Short Hair', 1),
#   ('Persian', 1),
#   ('Ragdoll', 1),
#   ('Turkish Angora', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'ND': [('Domestic Short Hair', 168),
#   ('Domestic Long Hair', 16),
#   ('Domestic Medium Hair', 16),
#   ('Tabby', 2),
#   ('American Shorthair', 1),
#   ('Calico', 1),
#   ('Russian Blue', 1),
#   ('Siamese', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Tortoiseshell', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'NE': [('Domestic Short Hair', 76),
#   ('Domestic Long Hair', 9),
#   ('Domestic Medium Hair', 7),
#   ('Calico', 2),
#   ('Dilute Calico', 2),
#   ('Dilute Tortoiseshell', 1),
#   ('Tabby', 1),
#   ('Tortoiseshell', 1),
#   ('Tuxedo', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'NH': [('Domestic Short Hair', 580),
#   ('Domestic Long Hair', 51),
#   ('Domestic Medium Hair', 48),
#   ('Tuxedo', 23),
#   ('Tabby', 19),
#   ('Tiger', 13),
#   ('Calico', 9),
#   ('Siamese', 9),
#   ('American Shorthair', 7),
#   ('Maine Coon', 5),
#   ('Himalayan', 4),
#   ('Torbie', 4),
#   ('Tortoiseshell', 4),
#   ('Dilute Tortoiseshell', 3),
#   ('Russian Blue', 3),
#   ('Bombay', 2),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Munchkin', 2),
#   ('Oriental Short Hair', 2),
#   ('American Bobtail', 1),
#   ('Bengal', 1),
#   ('Cornish Rex', 1),
#   ('Dilute Calico', 1),
#   ('Ragdoll', 1),
#   ('Siberian', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'NJ': [('Domestic Short Hair', 7786),
#   ('Tabby', 777),
#   ('Tuxedo', 340),
#   ('Domestic Medium Hair', 303),
#   ('Domestic Long Hair', 267),
#   ('American Shorthair', 229),
#   ('Calico', 196),
#   ('Tortoiseshell', 113),
#   ('Maine Coon', 74),
#   ('Tiger', 56),
#   ('Bombay', 53),
#   ('Siamese', 45),
#   ('Dilute Calico', 42),
#   ('Russian Blue', 41),
#   ('Dilute Tortoiseshell', 37),
#   ('Bengal', 26),
#   ('Torbie', 26),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 21),
#   ('Manx', 17),
#   ('American Bobtail', 15),
#   ('Persian', 14),
#   ('Abyssinian', 8),
#   ('British Shorthair', 8),
#   ('Turkish Van', 8),
#   ('Ragdoll', 7),
#   ('Burmese', 6),
#   ('Egyptian Mau', 6),
#   ('Norwegian Forest Cat', 6),
#   ('Snowshoe', 5),
#   ('Turkish Angora', 5),
#   ('Oriental Short Hair', 4),
#   ('Havana', 3),
#   ('Munchkin', 2),
#   ('Nebelung', 2),
#   ('Scottish Fold', 2),
#   ('American Curl', 1),
#   ('Birman', 1),
#   ('Devon Rex', 1),
#   ('Exotic Shorthair', 1),
#   ('Ocicat', 1),
#   ('Siberian', 1),
#   ('Sphynx / Hairless Cat', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Selkirk Rex', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'NM': [('Domestic Short Hair', 347),
#   ('Domestic Medium Hair', 43),
#   ('Domestic Long Hair', 33),
#   ('Tabby', 24),
#   ('Maine Coon', 13),
#   ('Tuxedo', 10),
#   ('Turkish Angora', 7),
#   ('Calico', 4),
#   ('Russian Blue', 3),
#   ('Siamese', 3),
#   ('American Shorthair', 2),
#   ('Bombay', 2),
#   ('Tortoiseshell', 2),
#   ('Turkish Van', 2),
#   ('Dilute Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Manx', 1),
#   ('Norwegian Forest Cat', 1),
#   ('Persian', 1),
#   ('Snowshoe', 1),
#   ('Tiger', 1),
#   ('Torbie', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'NV': [('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Domestic Long Hair', 0),
#   ('Domestic Medium Hair', 0),
#   ('Domestic Short Hair', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tabby', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Tortoiseshell', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'NY': [('Domestic Short Hair', 894),
#   ('Domestic Long Hair', 56),
#   ('Tiger', 52),
#   ('Domestic Medium Hair', 45),
#   ('Tabby', 43),
#   ('American Shorthair', 35),
#   ('Tuxedo', 23),
#   ('Calico', 22),
#   ('Tortoiseshell', 15),
#   ('Torbie', 8),
#   ('Dilute Calico', 5),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 4),
#   ('Maine Coon', 4),
#   ('Siamese', 4),
#   ('Dilute Tortoiseshell', 3),
#   ('Persian', 3),
#   ('Ragdoll', 3),
#   ('Bombay', 2),
#   ('Manx', 2),
#   ('Abyssinian', 1),
#   ('American Bobtail', 1),
#   ('American Curl', 1),
#   ('Bengal', 1),
#   ('Birman', 1),
#   ('Exotic Shorthair', 1),
#   ('Turkish Van', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'OH': [('Domestic Short Hair', 1837),
#   ('Domestic Long Hair', 107),
#   ('Domestic Medium Hair', 98),
#   ('American Shorthair', 70),
#   ('Calico', 51),
#   ('Maine Coon', 41),
#   ('Manx', 20),
#   ('Dilute Calico', 17),
#   ('Dilute Tortoiseshell', 12),
#   ('Burmese', 9),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 9),
#   ('American Bobtail', 8),
#   ('Exotic Shorthair', 5),
#   ('Abyssinian', 4),
#   ('Bengal', 3),
#   ('Bombay', 2),
#   ('British Shorthair', 2),
#   ('Applehead Siamese', 1),
#   ('Balinese', 1),
#   ('Himalayan', 1),
#   ('Japanese Bobtail', 1),
#   ('Munchkin', 1),
#   ('Ocicat', 1),
#   ('Ragamuffin', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Havana', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0)],
#  'OK': [],
#  'OR': [],
#  'PA': [],
#  'RI': [],
#  'SC': [],
#  'SD': [],
#  'TN': [],
#  'TX': [],
#  'UT': [],
#  'VA': [],
#  'VT': [],
#  'WA': [],
#  'WI': [],
#  'WV': [],
#  'WY': []}

# %%
total_count_per_state2 = {}
for state in states2:
    total = 0
    for k,v in sorted_cat2[state]:
        total += v
    total_count_per_state2[state] = total
total_count_per_state2
# Out:
# {'ME': 151,
#  'MI': 1459,
#  'MN': 1052,
#  'MO': 707,
#  'MS': 174,
#  'MT': 81,
#  'NC': 2668,
#  'ND': 206,
#  'NE': 100,
#  'NH': 796,
#  'NJ': 10557,
#  'NM': 503,
#  'NV': 0,
#  'NY': 1230,
#  'OH': 2302,
#  'OK': 0,
#  'OR': 0,
#  'PA': 0,
#  'RI': 0,
#  'SC': 0,
#  'SD': 0,
#  'TN': 0,
#  'TX': 0,
#  'UT': 0,
#  'VA': 0,
#  'VT': 0,
#  'WA': 0,
#  'WI': 0,
#  'WV': 0,
#  'WY': 0}

# %%
top5_cat_per_states2 = {}
ranks = ['top1','top2','top3','top4','top5']
for r in ranks:
    top5_cat_per_states2[r]=[]
for state in states2:
    i=0
    for k,v in sorted_cat2[state]:
        top5_cat_per_states2[ranks[i]].append(k)
        i+=1
        if i==5: break

# %%
top5_cat_per_states2
# Out:
# {'top1': ['Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Abyssinian',
#   'Domestic Short Hair',
#   'Domestic Short Hair'],
#  'top2': ['Domestic Long Hair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Domestic Medium Hair',
#   'American Bobtail',
#   'Domestic Long Hair',
#   'Domestic Long Hair'],
#  'top3': ['Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Tuxedo',
#   'Domestic Long Hair',
#   'American Curl',
#   'Tiger',
#   'Domestic Medium Hair'],
#  'top4': ['Tuxedo',
#   'Tabby',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'American Shorthair',
#   'Scottish Fold',
#   'Domestic Long Hair',
#   'Tabby',
#   'Calico',
#   'Tuxedo',
#   'Domestic Medium Hair',
#   'Tabby',
#   'American Shorthair',
#   'Domestic Medium Hair',
#   'American Shorthair'],
#  'top5': ['Bengal',
#   'American Shorthair',
#   'Tuxedo',
#   'Siamese',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Tuxedo',
#   'American Shorthair',
#   'Dilute Calico',
#   'Tabby',
#   'Domestic Long Hair',
#   'Maine Coon',
#   'American Wirehair',
#   'Tabby',
#   'Calico']}

# %% [markdown]
# Day3 Data

# %%
states3 = [ 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY']

# %%
url = "https://api.petfinder.com/v2/animals"
total_cat3 = {}
for s in states3:
    total_cat3[s] = {}
for loc in states3:
    for b in cat_breeds:
        payload={'type':"Cat","breed":b,'location':loc}
        response = requests.get(url, headers = header,params=payload)
        total_cat3[loc][b]=response.json()['pagination']['total_count']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-8c86fee1bab6> in <module>
#       7         payload={'type':"Cat","breed":b,'location':loc}
#       8         response = requests.get(url, headers = header,params=payload)
# ----> 9         total_cat3[loc][b]=response.json()['pagination']['total_count']
#
# KeyError: 'pagination'

# %%
sorted_cat3 = {}
for s in states3:
    #print(total_cat[s].items())
    sorted_cat3[s] = sorted(total_cat3[s].items(), key=lambda x:x[1], reverse = True)
sorted_cat3
# Out:
# {'OH': [('Domestic Short Hair', 1864),
#   ('Tabby', 201),
#   ('Domestic Long Hair', 106),
#   ('Domestic Medium Hair', 104),
#   ('American Shorthair', 70),
#   ('Tiger', 59),
#   ('Calico', 53),
#   ('Tuxedo', 44),
#   ('Maine Coon', 42),
#   ('Tortoiseshell', 42),
#   ('Russian Blue', 28),
#   ('Manx', 20),
#   ('Dilute Calico', 17),
#   ('Siamese', 16),
#   ('Dilute Tortoiseshell', 11),
#   ('Torbie', 11),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 9),
#   ('American Bobtail', 8),
#   ('Burmese', 8),
#   ('Bengal', 5),
#   ('Exotic Shorthair', 5),
#   ('Turkish Van', 5),
#   ('Abyssinian', 4),
#   ('Ragdoll', 4),
#   ('Bombay', 3),
#   ('British Shorthair', 2),
#   ('Snowshoe', 2),
#   ('Applehead Siamese', 1),
#   ('Balinese', 1),
#   ('Himalayan', 1),
#   ('Japanese Bobtail', 1),
#   ('Ocicat', 1),
#   ('Persian', 1),
#   ('Ragamuffin', 1),
#   ('Silver', 1),
#   ('Turkish Angora', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Havana', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'OK': [('Domestic Short Hair', 431),
#   ('Tabby', 49),
#   ('Domestic Medium Hair', 22),
#   ('Domestic Long Hair', 20),
#   ('Calico', 11),
#   ('Tuxedo', 11),
#   ('Siamese', 9),
#   ('Tortoiseshell', 7),
#   ('American Shorthair', 5),
#   ('American Bobtail', 4),
#   ('Torbie', 3),
#   ('Dilute Tortoiseshell', 2),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Abyssinian', 1),
#   ('Bombay', 1),
#   ('Chartreux', 1),
#   ('Egyptian Mau', 1),
#   ('Manx', 1),
#   ('Russian Blue', 1),
#   ('Snowshoe', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'OR': [('Domestic Short Hair', 16),
#   ('Domestic Long Hair', 2),
#   ('Siamese', 2),
#   ('Domestic Medium Hair', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tabby', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Tortoiseshell', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'PA': [('Domestic Short Hair', 4704),
#   ('Tabby', 381),
#   ('Domestic Medium Hair', 200),
#   ('Domestic Long Hair', 175),
#   ('Tuxedo', 97),
#   ('American Shorthair', 91),
#   ('Calico', 80),
#   ('Tortoiseshell', 52),
#   ('Maine Coon', 39),
#   ('Siamese', 39),
#   ('Dilute Calico', 28),
#   ('Dilute Tortoiseshell', 27),
#   ('Russian Blue', 20),
#   ('Tiger', 17),
#   ('Torbie', 15),
#   ('Persian', 14),
#   ('British Shorthair', 10),
#   ('Bengal', 9),
#   ('Exotic Shorthair', 8),
#   ('Bombay', 7),
#   ('Manx', 5),
#   ('Scottish Fold', 5),
#   ('Snowshoe', 5),
#   ('American Bobtail', 4),
#   ('Oriental Short Hair', 4),
#   ('Egyptian Mau', 3),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 3),
#   ('Turkish Van', 3),
#   ('Abyssinian', 2),
#   ('Himalayan', 2),
#   ('Munchkin', 2),
#   ('Norwegian Forest Cat', 2),
#   ('Turkish Angora', 2),
#   ('American Curl', 1),
#   ('Birman', 1),
#   ('Havana', 1),
#   ('Nebelung', 1),
#   ('Pixiebob', 1),
#   ('Ragdoll', 1),
#   ('Silver', 1),
#   ('Tonkinese', 1),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Ragamuffin', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'RI': [('Domestic Short Hair', 1406),
#   ('Domestic Long Hair', 117),
#   ('Domestic Medium Hair', 92),
#   ('Tabby', 79),
#   ('Tuxedo', 60),
#   ('Tiger', 40),
#   ('Calico', 38),
#   ('Egyptian Mau', 36),
#   ('American Shorthair', 35),
#   ('Tortoiseshell', 24),
#   ('Siamese', 15),
#   ('Persian', 13),
#   ('Maine Coon', 12),
#   ('Bengal', 10),
#   ('Bombay', 10),
#   ('Dilute Tortoiseshell', 8),
#   ('Torbie', 8),
#   ('Turkish Van', 4),
#   ('Exotic Shorthair', 3),
#   ('Himalayan', 3),
#   ('Russian Blue', 3),
#   ('Snowshoe', 3),
#   ('Abyssinian', 2),
#   ('Dilute Calico', 2),
#   ('Manx', 2),
#   ('Munchkin', 2),
#   ('Oriental Short Hair', 2),
#   ('Turkish Angora', 2),
#   ('American Bobtail', 1),
#   ('Applehead Siamese', 1),
#   ('Burmese', 1),
#   ('Cornish Rex', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Japanese Bobtail', 1),
#   ('Nebelung', 1),
#   ('Ragdoll', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Havana', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'SC': [('Domestic Short Hair', 1036),
#   ('American Shorthair', 81),
#   ('Tabby', 81),
#   ('Domestic Long Hair', 45),
#   ('Domestic Medium Hair', 43),
#   ('Tortoiseshell', 25),
#   ('Tuxedo', 25),
#   ('Calico', 19),
#   ('Siamese', 14),
#   ('Tiger', 6),
#   ('Bombay', 5),
#   ('Dilute Tortoiseshell', 3),
#   ('Russian Blue', 3),
#   ('Torbie', 3),
#   ('Turkish Van', 3),
#   ('American Bobtail', 2),
#   ('British Shorthair', 2),
#   ('Burmese', 2),
#   ('Maine Coon', 2),
#   ('Manx', 2),
#   ('Snowshoe', 2),
#   ('Abyssinian', 1),
#   ('Dilute Calico', 1),
#   ('Egyptian Mau', 1),
#   ('Exotic Shorthair', 1),
#   ('Havana', 1),
#   ('Himalayan', 1),
#   ('Oriental Short Hair', 1),
#   ('Persian', 1),
#   ('Pixiebob', 1),
#   ('Ragdoll', 1),
#   ('Siberian', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'SD': [('Tabby', 12),
#   ('Domestic Short Hair', 3),
#   ('Chartreux', 1),
#   ('Domestic Long Hair', 1),
#   ('Tiger', 1),
#   ('Tortoiseshell', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Domestic Medium Hair', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Manx', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siamese', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)],
#  'TN': [('Domestic Short Hair', 1072),
#   ('Tabby', 201),
#   ('Domestic Medium Hair', 129),
#   ('Domestic Long Hair', 52),
#   ('American Shorthair', 42),
#   ('Calico', 32),
#   ('Tortoiseshell', 31),
#   ('Tuxedo', 29),
#   ('Siamese', 22),
#   ('Russian Blue', 19),
#   ('Maine Coon', 11),
#   ('Torbie', 10),
#   ('American Bobtail', 7),
#   ('Manx', 7),
#   ('Dilute Tortoiseshell', 6),
#   ('Bengal', 5),
#   ('Bombay', 4),
#   ('Ragdoll', 4),
#   ('Tiger', 4),
#   ('Turkish Van', 4),
#   ('Abyssinian', 3),
#   ('Dilute Calico', 3),
#   ('Snowshoe', 3),
#   ('Sphynx / Hairless Cat', 3),
#   ('Burmese', 2),
#   ('Oriental Short Hair', 2),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Japanese Bobtail', 1),
#   ('Nebelung', 1),
#   ('Norwegian Forest Cat', 1),
#   ('Persian', 1),
#   ('Tonkinese', 1),
#   ('Turkish Angora', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Toyger', 0),
#   ('York Chocolate', 0)],
#  'TX': [('Domestic Short Hair', 232),
#   ('Domestic Medium Hair', 23),
#   ('American Shorthair', 12),
#   ('Tabby', 12),
#   ('Domestic Long Hair', 9),
#   ('Calico', 7),
#   ('Abyssinian', 2),
#   ('American Bobtail', 2),
#   ('Russian Blue', 2),
#   ('Siamese', 2),
#   ('Tuxedo', 2),
#   ('Bombay', 1),
#   ('British Shorthair', 1),
#   ('Burmese', 1),
#   ('Dilute Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Maine Coon', 1),
#   ('Manx', 1),
#   ('Tortoiseshell', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'UT': [('Domestic Short Hair', 318),
#   ('Domestic Medium Hair', 46),
#   ('Domestic Long Hair', 40),
#   ('Siamese', 10),
#   ('Tabby', 8),
#   ('American Shorthair', 4),
#   ('Calico', 4),
#   ('Manx', 3),
#   ('Russian Blue', 3),
#   ('Tortoiseshell', 3),
#   ('Bengal', 2),
#   ('Nebelung', 2),
#   ('Tuxedo', 2),
#   ('American Curl', 1),
#   ('Persian', 1),
#   ('Snowshoe', 1),
#   ('Torbie', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'VA': [('Domestic Short Hair', 2129),
#   ('Tabby', 195),
#   ('Domestic Medium Hair', 139),
#   ('Domestic Long Hair', 122),
#   ('Tuxedo', 65),
#   ('American Shorthair', 58),
#   ('Calico', 43),
#   ('Tortoiseshell', 30),
#   ('Bombay', 29),
#   ('Maine Coon', 27),
#   ('Siamese', 21),
#   ('Persian', 15),
#   ('Russian Blue', 15),
#   ('Torbie', 10),
#   ('Tiger', 9),
#   ('British Shorthair', 8),
#   ('Dilute Tortoiseshell', 6),
#   ('Oriental Short Hair', 6),
#   ('Dilute Calico', 5),
#   ('Exotic Shorthair', 5),
#   ('Scottish Fold', 5),
#   ('Manx', 4),
#   ('Abyssinian', 3),
#   ('American Bobtail', 3),
#   ('Bengal', 3),
#   ('Egyptian Mau', 3),
#   ('Norwegian Forest Cat', 3),
#   ('American Curl', 2),
#   ('Burmese', 2),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 2),
#   ('Himalayan', 2),
#   ('Snowshoe', 2),
#   ('Applehead Siamese', 1),
#   ('Birman', 1),
#   ('Munchkin', 1),
#   ('Ocicat', 1),
#   ('Ragamuffin', 1),
#   ('Ragdoll', 1),
#   ('Tonkinese', 1),
#   ('Turkish Van', 1),
#   ('American Wirehair', 0),
#   ('Balinese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Nebelung', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('York Chocolate', 0)],
#  'VT': [('Domestic Short Hair', 414),
#   ('Domestic Long Hair', 34),
#   ('Domestic Medium Hair', 30),
#   ('Tabby', 12),
#   ('Tiger', 9),
#   ('Tuxedo', 7),
#   ('Calico', 4),
#   ('Tortoiseshell', 4),
#   ('American Shorthair', 3),
#   ('Torbie', 3),
#   ('Siamese', 2),
#   ('American Bobtail', 1),
#   ('Burmese', 1),
#   ('Dilute Calico', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Himalayan', 1),
#   ('Maine Coon', 1),
#   ('Munchkin', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Manx', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'WA': [('Domestic Short Hair', 386),
#   ('Domestic Medium Hair', 45),
#   ('Domestic Long Hair', 39),
#   ('Tabby', 34),
#   ('American Shorthair', 19),
#   ('Tuxedo', 14),
#   ('Tortoiseshell', 11),
#   ('Calico', 9),
#   ('Bengal', 8),
#   ('Siamese', 7),
#   ('Manx', 5),
#   ('Maine Coon', 4),
#   ('Snowshoe', 3),
#   ('Bombay', 2),
#   ('American Bobtail', 1),
#   ('Munchkin', 1),
#   ('Persian', 1),
#   ('Russian Blue', 1),
#   ('Scottish Fold', 1),
#   ('Torbie', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'WI': [('Domestic Short Hair', 533),
#   ('Domestic Long Hair', 34),
#   ('Domestic Medium Hair', 30),
#   ('Tabby', 21),
#   ('Tiger', 13),
#   ('American Shorthair', 12),
#   ('Calico', 12),
#   ('Torbie', 6),
#   ('Tortoiseshell', 6),
#   ('Siamese', 5),
#   ('Tuxedo', 5),
#   ('Dilute Calico', 3),
#   ('Abyssinian', 2),
#   ('Maine Coon', 2),
#   ('Russian Blue', 2),
#   ('American Bobtail', 1),
#   ('Dilute Tortoiseshell', 1),
#   ('Manx', 1),
#   ('Munchkin', 1),
#   ('Persian', 1),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'WV': [('Domestic Short Hair', 697),
#   ('Domestic Medium Hair', 53),
#   ('Domestic Long Hair', 45),
#   ('American Shorthair', 23),
#   ('Calico', 14),
#   ('Bombay', 5),
#   ('Dilute Calico', 5),
#   ('Manx', 4),
#   ('American Bobtail', 3),
#   ('Dilute Tortoiseshell', 3),
#   ('Maine Coon', 3),
#   ('Persian', 2),
#   ('Bengal', 1),
#   ('Burmese', 1),
#   ('Egyptian Mau', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Oriental Short Hair', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0)],
#  'WY': []}

# %%
url = "https://api.petfinder.com/v2/animals"
payload={'type':"Cat","breed":"Tuxedo",'location':'AR'}
response = requests.get(url, headers = header,params=payload)
temp=response.json()['pagination']

# %%
temp
# Out:
# {'count_per_page': 20, 'total_count': 5, 'current_page': 1, 'total_pages': 1}

# %%
total_count_per_state3 = {}
for state in states3:
    total = 0
    for k,v in sorted_cat3[state]:
        total += v
    total_count_per_state3[state] = total
total_count_per_state3
# Out:
# {'OH': 2752,
#  'OK': 583,
#  'OR': 21,
#  'PA': 6063,
#  'RI': 2039,
#  'SC': 1415,
#  'SD': 19,
#  'TN': 1714,
#  'TX': 313,
#  'UT': 449,
#  'VA': 2979,
#  'VT': 530,
#  'WA': 592,
#  'WI': 691,
#  'WV': 862,
#  'WY': 0}

# %%
top5_cat_per_states3 = {}
ranks = ['top1','top2','top3','top4','top5']
for r in ranks:
    top5_cat_per_states3[r]=[]
for state in states3:
    i=0
    for k,v in sorted_cat3[state]:
        top5_cat_per_states3[ranks[i]].append(k)
        i+=1
        if i==5: break

# %%
top5_cat_per_states3
# Out:
# {'top1': ['Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Tabby',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair',
#   'Domestic Short Hair'],
#  'top2': ['Tabby',
#   'Tabby',
#   'Domestic Long Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'American Shorthair',
#   'Domestic Short Hair',
#   'Tabby',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair'],
#  'top3': ['Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Siamese',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Tabby',
#   'Chartreux',
#   'Domestic Medium Hair',
#   'American Shorthair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair'],
#  'top4': ['Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Domestic Medium Hair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Siamese',
#   'Domestic Long Hair',
#   'Tabby',
#   'Tabby',
#   'Tabby',
#   'American Shorthair'],
#  'top5': ['American Shorthair',
#   'Calico',
#   'Abyssinian',
#   'Tuxedo',
#   'Tuxedo',
#   'Domestic Medium Hair',
#   'Tiger',
#   'American Shorthair',
#   'Domestic Long Hair',
#   'Tabby',
#   'Tuxedo',
#   'Tiger',
#   'American Shorthair',
#   'Tiger',
#   'Calico']}

# %% [markdown]
# Day4

# %%
states4 = ['WV', 'WY']

# %%
url = "https://api.petfinder.com/v2/animals"
total_cat4 = {}
for s in states4:
    total_cat4[s] = {}
for loc in states4:
    for b in cat_breeds:
        payload={'type':"Cat","breed":b,'location':loc}
        response = requests.get(url, headers = header,params=payload)
        total_cat4[loc][b]=response.json()['pagination']['total_count']

# %%
sorted_cat4 = {}
for s in states4:
    #print(total_cat[s].items())
    sorted_cat4[s] = sorted(total_cat4[s].items(), key=lambda x:x[1], reverse = True)
sorted_cat4
# Out:
# {'WV': [('Domestic Short Hair', 697),
#   ('Tabby', 78),
#   ('Domestic Medium Hair', 53),
#   ('Domestic Long Hair', 45),
#   ('Tuxedo', 26),
#   ('American Shorthair', 23),
#   ('Calico', 14),
#   ('Siamese', 13),
#   ('Tortoiseshell', 10),
#   ('Russian Blue', 7),
#   ('Bombay', 5),
#   ('Dilute Calico', 5),
#   ('Manx', 4),
#   ('Torbie', 4),
#   ('American Bobtail', 3),
#   ('Dilute Tortoiseshell', 3),
#   ('Maine Coon', 3),
#   ('Persian', 2),
#   ('Snowshoe', 2),
#   ('Bengal', 1),
#   ('Burmese', 1),
#   ('Egyptian Mau', 1),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 1),
#   ('Oriental Short Hair', 1),
#   ('Silver', 1),
#   ('Tiger', 1),
#   ('Abyssinian', 0),
#   ('American Curl', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Birman', 0),
#   ('British Shorthair', 0),
#   ('Burmilla', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Exotic Shorthair', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Singapura', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tonkinese', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('York Chocolate', 0)],
#  'WY': [('Domestic Short Hair', 32),
#   ('Domestic Long Hair', 3),
#   ('Domestic Medium Hair', 3),
#   ('Manx', 1),
#   ('Siamese', 1),
#   ('Tortoiseshell', 1),
#   ('Abyssinian', 0),
#   ('American Bobtail', 0),
#   ('American Curl', 0),
#   ('American Shorthair', 0),
#   ('American Wirehair', 0),
#   ('Applehead Siamese', 0),
#   ('Balinese', 0),
#   ('Bengal', 0),
#   ('Birman', 0),
#   ('Bombay', 0),
#   ('British Shorthair', 0),
#   ('Burmese', 0),
#   ('Burmilla', 0),
#   ('Calico', 0),
#   ('Canadian Hairless', 0),
#   ('Chartreux', 0),
#   ('Chausie', 0),
#   ('Chinchilla', 0),
#   ('Cornish Rex', 0),
#   ('Cymric', 0),
#   ('Devon Rex', 0),
#   ('Dilute Calico', 0),
#   ('Dilute Tortoiseshell', 0),
#   ('Egyptian Mau', 0),
#   ('Exotic Shorthair', 0),
#   ('Extra-Toes Cat / Hemingway Polydactyl', 0),
#   ('Havana', 0),
#   ('Himalayan', 0),
#   ('Japanese Bobtail', 0),
#   ('Javanese', 0),
#   ('Korat', 0),
#   ('LaPerm', 0),
#   ('Maine Coon', 0),
#   ('Munchkin', 0),
#   ('Nebelung', 0),
#   ('Norwegian Forest Cat', 0),
#   ('Ocicat', 0),
#   ('Oriental Long Hair', 0),
#   ('Oriental Short Hair', 0),
#   ('Oriental Tabby', 0),
#   ('Persian', 0),
#   ('Pixiebob', 0),
#   ('Ragamuffin', 0),
#   ('Ragdoll', 0),
#   ('Russian Blue', 0),
#   ('Scottish Fold', 0),
#   ('Selkirk Rex', 0),
#   ('Siberian', 0),
#   ('Silver', 0),
#   ('Singapura', 0),
#   ('Snowshoe', 0),
#   ('Somali', 0),
#   ('Sphynx / Hairless Cat', 0),
#   ('Tabby', 0),
#   ('Tiger', 0),
#   ('Tonkinese', 0),
#   ('Torbie', 0),
#   ('Toyger', 0),
#   ('Turkish Angora', 0),
#   ('Turkish Van', 0),
#   ('Tuxedo', 0),
#   ('York Chocolate', 0)]}

# %%
total_count_per_state4 = {}
for state in states4:
    total = 0
    for k,v in sorted_cat4[state]:
        total += v
    total_count_per_state4[state] = total
total_count_per_state4
# Out:
# {'WV': 1004, 'WY': 41}

# %%
top5_cat_per_states4 = {}
ranks = ['top1','top2','top3','top4','top5']
for r in ranks:
    top5_cat_per_states4[r]=[]
for state in states4:
    i=0
    for k,v in sorted_cat4[state]:
        top5_cat_per_states4[ranks[i]].append(k)
        i+=1
        if i==5: break
top5_cat_per_states4
# Out:
# {'top1': ['Domestic Short Hair', 'Domestic Short Hair'],
#  'top2': ['Tabby', 'Domestic Long Hair'],
#  'top3': ['Domestic Medium Hair', 'Domestic Medium Hair'],
#  'top4': ['Domestic Long Hair', 'Manx'],
#  'top5': ['Tuxedo', 'Siamese']}

# %% [markdown]
# ## This is the final each states cat data

# %%
total_per_state = {'AK': 2,
 'AL': 518,
 'AR': 232,
 'AZ': 1013,
 'CA': 828,
 'CO': 754,
 'CT': 6621,
 'DC': 4734,
 'DE': 6087,
 'FL': 2560,
 'GA': 1601,
 'HI': 110,
 'IA': 992,
 'ID': 58,
 'IL': 1376,
 'IN': 2186,
 'KS': 293,
 'KY': 2088,
 'LA': 451,
 'MA': 1266,
 'MD': 4992,
 'ME': 151,
 'MI': 1459,
 'MN': 1052,
 'MO': 707,
 'MS': 174,
 'MT': 81,
 'NC': 2668,
 'ND': 206,
 'NE': 100,
 'NH': 796,
 'NJ': 10557,
 'NM': 503,
 'NV': 0,
 'NY': 1230,
 'OH': 2752,
 'OK': 583,
 'OR': 21,
 'PA': 6063,
 'RI': 2039,
 'SC': 1415,
 'SD': 19,
 'TN': 1714,
 'TX': 313,
 'UT': 449,
 'VA': 2979,
 'VT': 530,
 'WA': 592,
 'WI': 691,
 'WV': 1004,
 'WY': 41}

# %%
c = 0
for i in total_per_state:
    c += total_per_state[i]
print(c)
# Out:
# 79651

# %%
top5_cat_total = {'top1': ['Bombay',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  '',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Tabby',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair',
  'Domestic Short Hair', 
  'Domestic Short Hair'],
 'top2': ['Domestic Short Hair',
  'American Shorthair',
  'Tabby',
  'Tabby',
  'Tabby',
  'Domestic Medium Hair',
  'Tabby',
  'Tabby',
  'Tabby',
  'Tabby',
  'Tabby',
  'Domestic Medium Hair',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Tabby',
  'Domestic Medium Hair',
  'Tabby',
  'Tabby',
  'Domestic Long Hair',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Tabby',
  'Tabby',
  'Tabby',
  'Domestic Medium Hair',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Tabby',
  'Domestic Medium Hair',
  '',
  'Domestic Long Hair',
  'Tabby',
  'Tabby',
  'Domestic Long Hair',
  'Tabby',
  'Domestic Long Hair',
  'American Shorthair',
  'Domestic Short Hair',
  'Tabby',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Tabby', 
  'Domestic Long Hair'],
 'top3': ['',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Tuxedo',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Tabby',
  'Domestic Medium Hair',
  'Tabby',
  'Tabby',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Tuxedo',
  'Domestic Long Hair',
  '',
  'Tiger',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Siamese',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Tabby',
  'Chartreux',
  'Domestic Medium Hair',
  'American Shorthair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Medium Hair', 
  'Domestic Medium Hair'],
 'top4': ['',
  'Tabby',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Siamese',
  'Tabby',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'American Shorthair',
  'Domestic Long Hair',
  'American Shorthair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'American Shorthair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Tabby',
  'Domestic Long Hair',
  'Tuxedo',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'American Shorthair',
  'Scottish Fold',
  'Domestic Long Hair',
  'Tabby',
  'Calico',
  'Tuxedo',
  'Domestic Medium Hair',
  'Tabby',
  '',
  'Domestic Medium Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Domestic Medium Hair',
  'Domestic Long Hair',
  'Tabby',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Domestic Long Hair',
  'Tabby',
  'Siamese',
  'Domestic Long Hair',
  'Tabby',
  'Tabby',
  'Tabby',
  'Domestic Long Hair', 
  'Manx'],
 'top5': ['',
  'Siamese',
  'Tuxedo',
  'Tuxedo',
  'Calico',
  'Siamese',
  'Domestic Long Hair',
  'Tuxedo',
  'Tuxedo',
  'Tuxedo',
  'American Shorthair',
  'Tortoiseshell',
  'Tuxedo',
  'Extra-Toes Cat / Hemingway Polydactyl',
  'Tortoiseshell',
  'American Shorthair',
  'Siamese',
  'Tortoiseshell',
  'Calico',
  'Tuxedo',
  'Tuxedo',
  'Bengal',
  'American Shorthair',
  'Tuxedo',
  'Siamese',
  'Domestic Medium Hair',
  'Tabby',
  'Tuxedo',
  'American Shorthair',
  'Dilute Calico',
  'Tabby',
  'Domestic Long Hair',
  'Maine Coon',
  '',
  'Tabby',
  'American Shorthair',
  'Calico',
  'Abyssinian',
  'Tuxedo',
  'Tuxedo',
  'Domestic Medium Hair',
  'Tiger',
  'American Shorthair',
  'Domestic Long Hair',
  'Tabby',
  'Tuxedo',
  'Tiger',
  'American Shorthair',
  'Tiger',
  'Calico',
  'Siamese']}

# %%
with open('each_state_cat.csv', mode = 'w', newline = '') as w:
    writer = csv.DictWriter(w, fieldnames=['state', 'count', 'top1', 'top2', 'top3', 'top4', 'top5'])
    writer.writeheader()
    i = 0
    for key, value in total_per_state.items():
        writer.writerow({'state': key, 'count': value, 'top1': top5_cat_total['top1'][i]
                        , 'top2': top5_cat_total['top2'][i]
                        , 'top3': top5_cat_total['top3'][i]
                        , 'top4': top5_cat_total['top4'][i]
                        , 'top5': top5_cat_total['top5'][i]})
        i += 1

# %%
df = pd.read_csv('each_state_cat.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' + 'Top1: '+ df['top1'] +'<br>' + 'Top2: '+ df['top2'] + '<br>' + 'Top3: '+ df['top3'] + '<br>' + 'Top4: '+ df['top4'] + '<br>' + 'Top5: '+ df['top5'] 
data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['state'],
        z = df['count'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Popularity"
        )
    ) ]

layout = dict(
        title = 'Top 5 cats in each state',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="fc2fc4e2-4c20-47e3-ac91-20d68cb49673" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc2fc4e2-4c20-47e3-ac91-20d68cb49673")) {                    Plotly.newPlot(                        "fc2fc4e2-4c20-47e3-ac91-20d68cb49673",                        [{"autocolorscale":false,"colorbar":{"title":{"text":"Popularity"}},"colorscale":[[0.0,"rgb(242,240,247)"],[0.2,"rgb(218,218,235)"],[0.4,"rgb(188,189,220)"],[0.6,"rgb(158,154,200)"],[0.8,"rgb(117,107,177)"],[1.0,"rgb(84,39,143)"]],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"marker":{"line":{"color":"rgb(255,255,255)","width":2}},"text":["AK<br>Top1: Bombay<br>Top2: Domestic Short Hair<br>Top3: nan<br>Top4: nan<br>Top5: nan","AL<br>Top1: Domestic Short Hair<br>Top2: American Shorthair<br>Top3: Domestic Medium Hair<br>Top4: Tabby<br>Top5: Siamese","AR<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Long Hair<br>Top4: Domestic Medium Hair<br>Top5: Tuxedo","AZ<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tuxedo","CA<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Siamese<br>Top5: Calico","CO<br>Top1: Domestic Short Hair<br>Top2: Domestic Medium Hair<br>Top3: Domestic Long Hair<br>Top4: Tabby<br>Top5: Siamese","CT<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Tuxedo<br>Top4: Domestic Medium Hair<br>Top5: Domestic Long Hair","DC<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tuxedo","DE<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tuxedo","FL<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: American Shorthair<br>Top5: Tuxedo","GA<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: American Shorthair","HI<br>Top1: Domestic Short Hair<br>Top2: Domestic Medium Hair<br>Top3: Tabby<br>Top4: American Shorthair<br>Top5: Tortoiseshell","IA<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tuxedo","ID<br>Top1: Domestic Short Hair<br>Top2: Domestic Long Hair<br>Top3: Tabby<br>Top4: Domestic Medium Hair<br>Top5: Extra-Toes Cat / Hemingway Polydactyl","IL<br>Top1: Domestic Short Hair<br>Top2: Domestic Medium Hair<br>Top3: Tabby<br>Top4: Domestic Long Hair<br>Top5: Tortoiseshell","IN<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: American Shorthair","KS<br>Top1: Domestic Short Hair<br>Top2: Domestic Medium Hair<br>Top3: Domestic Long Hair<br>Top4: American Shorthair<br>Top5: Siamese","KY<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tortoiseshell","LA<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Calico","MA<br>Top1: Domestic Short Hair<br>Top2: Domestic Long Hair<br>Top3: Domestic Medium Hair<br>Top4: Tabby<br>Top5: Tuxedo","MD<br>Top1: Domestic Short Hair<br>Top2: Tabby<br>Top3: Domestic Medium Hair<br>Top4: Domestic Long Hair<br>Top5: Tuxedo","ME<br>Top1: Domestic Short Hair<br>Top2: Domestic Long Hair<br>Top3: Domestic Medium Hair<br>Top4: Tuxedo<br>Top5: Bengal","MI<br>Top1: Domestic Short Hair<br>Top2: Domestic Long Hair<br>Top3: Domestic Medium Hair<br>Top4: Tabby<br>Top5: American ...

# %%
pio.write_html(fig, file='top_cat.html', auto_open=True)
